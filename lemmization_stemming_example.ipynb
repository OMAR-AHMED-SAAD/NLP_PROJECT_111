# %%
# imports
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re 
import pyarabic.araby as araby
from nltk.corpus import stopwords
import nltk
from typing import List
from tqdm.notebook import tqdm
import arabic_reshaper 
from bidi.algorithm import get_display
import json 
import seaborn as sns

# %%
def data_loader(dir_path: str, n: int, read_metadata: bool = False, tags: str = "keywords", creator: str = "") -> pd.DataFrame:
    """
    Load episode transcripts from text files and optionally add metadata.

    :param dir_path: Path to the directory containing 'raw_data' and 'metadata' folders.
    :param n: Number of episodes to read.
    :param read_metadata: Whether to include metadata from JSON files.
    :return: A pandas DataFrame.
    """
    data_dir_path = os.path.join(dir_path, "raw_data")
    metadata_dir_path = os.path.join(dir_path, "metadata") if read_metadata else None

    episodes = []
    
    # Read the first `n` .txt files
    txt_files = [file for file in os.listdir(data_dir_path) if file.endswith(".txt")][:n]

    for file in txt_files:
        base_name = file.replace(".txt", "")
        file_path = os.path.join(data_dir_path, file)

        with open(file_path, 'r', encoding="utf-8") as f:
            episode_data = {"file_name": base_name, "episode_transcript": f.read().strip()}

        # Read metadata if needed
        if read_metadata:
            metadata_path = os.path.join(metadata_dir_path, base_name + ".json")
            if os.path.exists(metadata_path):
                with open(metadata_path, 'r', encoding="utf-8") as f:
                    json_file = json.load(f)
                    episode_data["length"] = json_file.get("length", None)
                    episode_data["tags"] = json_file.get(tags, None)
            else:
                episode_data["length"] = None  # Handle missing metadata
                episode_data["tags"] = None

        episodes.append(episode_data)
    df = pd.DataFrame(episodes)
    df['creator'] = creator
    return df

# %%
# Folders
DATA_FOLDERS = ["youtube/Al_Mokhbir_Al_Eqtisadi/raw_data", 'youtube/Da7ee7/raw_data', 'youtube/Fi_Al_Hadaraa/raw_data']
META_DATA = ["youtube/Al_Mokhbir_Al_Eqtisadi/metadata", 'youtube/Da7ee7/metadata', 'youtube/Fi_Al_Hadaraa/metadata']

n = 1000
MOKHBIR_DIR = "./youtube/Al_Mokhbir_Al_Eqtisadi/"
DA7EE7_DIR = "./youtube/Da7ee7/"
HADARAA_DIR = "./youtube/Fi_Al_Hadaraa/"
mokhbir_df = data_loader(MOKHBIR_DIR, n, read_metadata=True, creator="Al Mokhbir Al Eqtisadi")
mokhbir_df.head()
# Out:
#                                            file_name  \
# 0  المخبر_الاقتصادي___كيف_أصبح_أصدقاء_إسرائيل...
# 1  المخبر_الاقتصادي__كيف_ترفع_الشركات_أسعار_المن...
# 2  المخبر_الاقتصادي__لماذا_تبيع_الصين_كميات_كبيرة...
# 3  المخبر_الاقتصادي__لماذا_سترتفع_أسعار_تذاكر_ال...
# 4  المخبر_الاقتصادي__لماذا_تخفي_أمريكا_السلاح_ال...
#
#                                   episode_transcript    length  \
# 0  عمان وقطر والبحرين والسعوديه دي هي الدول\nالعر...  00:22:52
# 1  في اواخر 2016 حصل هجوم كبير من\nالمستهلكين في ...  00:15:12
# 2  في نوفمبر سنه 1971 وزراء ماليه مجموعه\nالدول ا...  00:16:53
# 3  في شهر مايو اللي فات\n23 شركة طيران\nأعلنوا إن...  00:14:23
# 4  في صباح يوم 19 اكتوبر 2023 الرئيس\nالامريكي جو...  00:20:25
#
#                                                 tags                 creator
# 0  [اسرائيل, اشرف ابراهيم, البرلمان البريطاني, ال...  Al Mokhbir Al Eqtisadi
# 1  [أحجام المنتجات وأسعارها, أسعار المنتجات ترتفع...  Al Mokhbir Al Eqtisadi
# 2  [أمريكا, أوروبا, اشرف ابراهيم, البنك المركزي ا...  Al Mokhbir Al Eqtisadi
# 3  [Airlines, fly, tickets, أسعار التذاكر, الخطوط...  Al Mokhbir Al Eqtisadi
# 4  [AJ+, AJ+ الدحيح, AJ+ عربي, AJ+ كبريت, AJ+ مع ...  Al Mokhbir Al Eqtisadi

# %%
df = pd.read_csv('final_preprocessed_dataset.csv')
df.head()
# Out:
#                                   episode_transcript                 creator  \
# 0  عمان وقطر والبحرين والسعوديه دي هي الدول\nالعر...  Al_Mokhbir_Al_Eqtisadi
# 1  الراجل دا أنا عمري ما شفت حد زيه قبل كدا\nتحس ...  Al_Mokhbir_Al_Eqtisadi
# 2  في نوفمبر سنه 1971 وزراء ماليه مجموعه\nالدول ا...  Al_Mokhbir_Al_Eqtisadi
# 3  في اواخر شهر سبتمبر سنه 2023 وزير\nالماليه الن...  Al_Mokhbir_Al_Eqtisadi
# 4  في الساعات الاولى من صباح يوم 31 مايو\nسنه 201...  Al_Mokhbir_Al_Eqtisadi
#
#      length   sarcasm  sentiment_score  \
# 0  00:22:52  غير ساخر         0.433861
# 1  00:14:45  غير ساخر         0.751848
# 2  00:16:53      ساخر         0.006446
# 3  00:24:44      ساخر         0.070738
# 4  00:14:11  غير ساخر         0.249777
#
#                                   cleaned_transcript  \
# 0  عمان وقطر والبحرين والسعوديه الدول العربيه الا...
# 1  الراجل عمري شفت زيه تحس عبارة مزيج خليط توماس ...
# 2  وزراء ماليه مجموعه الدول العشر الكبرى الجي اجت...
# 3  اواخر وزير الماليه النيجيري اديبايو اووي ايدون...
# 4  الساعات وتحديدا الساعه فجرا قوات كوماندوز اسرا...
#
#                               gemini_classifications  \
# 0   امهات غزه, اطفال غزه, قتل الاطفال, رفح, الاحتلال
# 1  العلاقات البريطانية الإسرائيلية, اللوبي الإسرا...
# 2  الهجرة المغاربية إلى فرنسا, الاستعمار الفرنسي ...
# 3  الحرب التكنولوجية بين أمريكا والصين, صناعة أشب...
# 4  جوهرة كوه نور, الاستعمار البريطاني للهند, شركة...
#
#        tf_idf_classifications  \
# 0            عينكم, خلوا, قصه
# 1  المحافظين, الاسرائيلي, حزب
# 2  المغاربة, المغاربية, فرنسا
# 3            الصين, دا, أشباه
# 4            كوه, نور, الماسة
#
#                                                    y
# 0  امهات غزه, اطفال غزه, قتل الاطفال, رفح, الاحتل...
# 1  العلاقات البريطانية الإسرائيلية, اللوبي الإسرا...
# 2  الهجرة المغاربية إلى فرنسا, الاستعمار الفرنسي ...
# 3  الحرب التكنولوجية بين أمريكا والصين, صناعة أشب...
# 4  جوهرة كوه نور, الاستعمار البريطاني للهند, شركة...

# %%
df['cleaned_transcript'].iloc[0]
# Out:
# 'عمان وقطر والبحرين والسعوديه الدول العربيه الاربعه زارها ملك بريطانيا وامير ويلز تشارلز الثالث زوجته اميره ويلز الراحله الاميره ديانا تشارلز وديانا لفوا الدول العربيه الاربعه رحله مدتها الحقيقه الرحله اعتياديه الىى كبير كانش شيء مميز مثيل للاهتمام حواليها فجاه مرور الرحله رجعتي بقت محط اهتمام وسائل الاعلام البريطانيه صحيفه الديلي ميل البريطانيه لقت الارشيف العام رساله مؤرخه بتاريخ تشارلز باعتها لصديقه الكاتب الجنوب افريقي لورانس فاندر بوست الرساله تشارلز بيحكي للورانس زيارته للدول العربيه لسه خلصانه وبيشرح الزياره ساعدته يفهم افضل وجهه نظر العرب اسرائيل المهم المهم السياق تشارلس لصديقه بالنص رئيس امريكي عنده الشجاعه يقف وش اللوبي اليهودي الولايات المتحده ويواجهه وبعدين استدرك وكتب اعتقد ساذج افكر يحصل الرساله بمجرد خرجت للنور قلبت الدنيا تشارلز وقتها وريث العرش البريطاني وقدام الهجوم الكاسح انصار الاحتلال الاسرائيلي المتحدث القصر بتاعه طلع جماعه المكتوب الرساله اراء الامير تشارلز الشخصيه اراء الشخصيات قابلها زيارته للدول العربيه الحقيقه تنصل تشارلز كتبه رسالته متوقع كبير بريطانيا نعرفها صعب تتسامح اراء النوع جايه مواطن بريطاني عادي مالوش حيثيه بالك خرجت الشخص الكل عارف هيبقى ملك بريطانيا المستقبلي وفاه والدته الملكه اليزابيث تشارلز رسالته عملت مشاكل بيعاير امريكا اللوبي المؤيد للاحتلال الاسرائيلي يزال مؤثر سياساتها الشرق الاوسط تلف الايام وبريطانيا تبقى المكان بيتواجد اقوى لوبي جماعه ضغط مؤيده للاحتلال الاسرائيلي اوروبا الغربيه كلها اللوبي الاسرائيلي لندن ومؤثر وجيبه عمران وبرغم حدش بيتكلم تقريبا التركيز كله اللوبي الموجود واشنطن بالتاكيد قوه وفعليه بالنسبه للاحتلال الاسرائيلي لانه بياثر سياسه اقوى دوله العالم التاثير اعضاء الكونجرس نفهم سياسه الولايات المتحده الاحتلال الاسرائيلي والقضيه الفلسطينيه والعرب نتعرف نشاط مجموعات الضغط المؤيده للاحتلال ايبات كنا حكينا قصتها حلقه مهمه اسمها يحكم امريكا الامر بالنسبه بريطانيا نقدر نفهم سر التاييد البريطاني الكاسح للاحتلال الاسرائيلي عدوانه غزه نفهم الدور بيلعبوا الاسرائيليين السياسه البريطانيه ورا الكواليس هندردش حلقه اشرف ابراهيم المخبر الاقتصادي بلس الحكومه البريطانيه بالكامل تقريبا ومعاها ثلث اعضاء البرلمان البريطاني معزومين الغدا فندق الانتركونتيننتال الموجود وسط العاصمه لندن وخليني احكي فكره سريعه بيتغدى يومها بنتكلم رئيس وزراء بريطانيا ريشي سوناك ومعاه وزير حالي حكومته راسهم وزير الخارجيه ديفيد كاميرون الحكومه البريطانيه كلها تقريبا بتتغدى عارف تعرفه الحكومه البريطانيه كلها بعضها اصلا وزير وزيرين حضرو الغدا الفاخر معمول الانتركونتيننتال غصب عنهم عندهم ارتباطات قدروش يلغوها المهم الغدا برده حضروا عضو اعضاء البرلمان البريطاني التابعين لحزب المحافظين الحاكم بالاضافه لاربع رؤساء وزراء سابقين لبريطانيا بريطانيا الرسميه كلها تقريبا بتتغدى فيش حدث بريطانيا بيتجمع الاسماء كلها يخليك تسال عزمهم العزومه مهم مهم صحيح صاحب العزومه مهم ومهم راعي الحفل بيتعمل بالمناسبه مؤسسه اسمها كونسيف فرينز اوف اسرائيل اصدقاء اسرائيل حزب المحافظين والمؤسسه معروفه اختصارا سي المؤسسه نار عالم لندن الاقل بالنسبه للسياسيين مافيش سياسي لندن توجهه انتماءه الحزبي يعرفش السي عندنا الوطن العربي المؤسسه معروفه كبير رغم بذور تاسيسها علاقه مباشره بينها وقبل احكي الحكومه البريطانيه بتعمل الغدا وداها خليني اشرح السي وليه ماحدش الحكومه البريطانيه بيفوت الغدا بتاعها وخلونا نبدا الحكايه العنوان كتبته صحيفه الساندي تايمز البريطانيه وتحديدا العنوان بيقول بريتين اويل سيف وي بيهيف اور سفز نفط بريطانيا امن احترمنا نفسنا وتصرفنا كويس العنوان الصحيفه البريطانيه كتبته وقت الدول الغربيه كلها حاله زعر الدول العربيه المنتجه للنفط راسها المملكه العربيه السعوديه قررت حظر تصدير النفط للدول المسند للاحتلال الاسرائيلي حرب اكتوبر خضها الجيشين المصري والسوري المحتل الاسرائيلي عكس الولايات المتحده انحازت واضح للاسرائيليين بريطانيا فضلت مصلحه لاحتها الشخصيه وقررت تنقب الصراع بقدر الامكان تتجنب غضب الدول العربيه المنتجه للنفط بتزود بريطانيا بجزء كبير احتياجاتها النفط السياق الحكومه البريطانيه بقياده زعيم حزب المحافظين وقتها ادوارد هيث قررت حظر تصدير الاسلحه لاطراف الحرب الاحتلال الاسرائيلي ودي ضربه كبيره بالنسبه للاسرائيليين معناه حرمانهم قطع غيار دبابات سنترين البريطانيه الجيش الاسرائيلي بيعتمد كبير صد الهجوم المصري والسوري الحكومه البريطانيه رفضت تسمح للامريكيين انهم يستخدموا القواعد البريطانيه امداد الاسرائيليين بالعتاد والسلاح الموقف البر ...

# %%
from farasa.stemmer import FarasaStemmer

farasa_stemmer = FarasaStemmer(interactive=True)

def stem_text(text: str) -> str:
    return farasa_stemmer.stem(text)
text = df['cleaned_transcript'].iloc[0]
stem_text(text)
# Out:
# [2025-03-09 17:22:58,168 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# 'عمان قطر بحرين سعودي دولة عربيه اربعه زار ملك بريطانيا أمير ويلز تشارلز ثالث زوجة أمير ويلز راحل اميره ديانا تشارلز وادي لف دولة عربيه اربعه رحل مدة حقيقه رحل اعتيادي الىى كبير كانش شيء مميز مثيل اهتمام حوالي فج مرور رحل رجعة قت محط اهتمام وسيلة اعلام بريطاني صحيف ديلي ميل بريطاني قت ارشيف عام رسال مؤرخ تاريخ تشارلز باعة صديق كاتب جنوب افريقي لورانس فاندر بوست رساله تشارلز حكى لورانس زيارة دولة عربيه لس خلص شرح زياره ساعد فهم أفضل وجه نظر عربي اسرائيل مهم مهم سياق تشارلس صديق نص رئيس امريكي عند شجاعه وقف وش لوبي يهودي ولاية المتحده واجه بعد استدرك كتب اعتقد ساذج افكر حصل رساله مجرد خرج نور قلب دنيا تشارلز وقت وريث عرش بريطاني قدام هجوم كاسح أنصار احتلال إسرائيلي متحدث قصر بتاع طلع جماع مكتوب رساله آراء امير تشارلز شخصيه آراء شخصية قابل زيارة دولة عربيه حقيقه تنصل تشارلز كتب رسالة متوقع كبير بريطانيا عرف صعب تسامح آراء نوع جايه مواطن بريطاني عادي مالوش حيث بال خرج شخص كل عارف هيبقى ملك بريطانيا مستقبلي وفى والد ملك إليزابيث تشارلز رسالة عمل مشكلة يعاير أمريكا لوبي مؤيد احتلال إسرائيلي زال مؤثر سياسة شرق أوسط تلف يوم بريطانيا بقي مكان تواجد أقوى لوبي جماع ضغط مؤيد احتلال إسرائيلي أوروبا غربي كل لوبي إسرائيلي لندن مؤثر جيب عمران رغم حدش تكلم تقريب تركيز كل لوبي موجود واشنطون تأكيد قوه على نسب احتلال إسرائيلي لان ياثر سياس أقوى دولة عالم تاثير أعضاء كونجرس فهم سياس ولاية المتحده احتلال إسرائيلي قضيه فلسطينيه عرب تعرف نشاط مجموعة ضغط مؤيد احتلال ايب كان حكى قصة حلق مهم اسم حكم أمريكا أمر نسب بريطانيا قدر فهم سر تاييد بريطاني كاسح احتلال إسرائيلي عدوان غز فهم دور بيلعبوا إسرائيلي سياسه بريطاني ورا كوليس هندردش حلق أشرف إبراهيم مخبر اقتصادي لس حكومه بريطاني كامل تقريب معا ثلث أعضاء برلمان بريطاني معزومين غد فندق انتركونتيننتال موجود وسط عاصمه لندن خليني احكي فكر سريع يتغدى يوم تكلم رئيس وزير بريطانيا ريشي سوناك معا وزير حال حكومة رأس وزير خارجيه ديفيد كمرون حكومه بريطاني كل تقريب تتغدى عارف عرف حكومه بريطاني كل بعض أصل وزير وزير حضرو غد فاخر معمول انتركونتيننتال غصب عن عند ارتباط قدروش لغا مهم غد رد حضر عضو أعضاء برلمان بريطاني تابع حزب محافظ حاكم اضافه أربع رئيس وزير سابق بريطانيا بريطانيا رسميه كل تقريب تتغدى فيش حدث بريطانيا تجمع اسم كل يخليك تسال عزم عزومه مهم مهم صحيح صاحب عزومه مهم مهم راعي حفل يتعمل مناسب مؤسس اسم كونسيف فرينز أوف اسرائيل أصدقاء اسرائيل حزب محافظ مؤسس معروف اختصار سي مؤسس نار عالم لندن أقل نسب سياسي مافيش سياسي لندن توجه انتماء حزبي يعرفش سي عند وطن عربي مؤسس معروف كبير رغم بذر تأسيس علاق مباشر بين قبل احكي حكومه بريطاني عمل غد ود خليني أشرح سي ولي ماحدش حكومه بريطاني فات غد بتاع خلا نبدأ حكايه عنوان كتب صحيف ساندي تايمز بريطاني تحديد عنوان قال بريتين أويل سيف وي يهيف اور سفز نفط بريطانيا أمن احترم نفس تصرف كويس عنوان صحيفه بريطاني كتب وقت دولة غربي كل حال زعر دولة عربيه منتج نفط راسي مملكه عربيه السعوديه قرر حظر تصدير نفط دولة مسند احتلال إسرائيلي حرب أكتوبر خض جيش مصري سوري محتل إسرائيلي عكس ولاية المتحده انحاز واضح اسرائيلي بريطانيا فضل مصالح لاح شخصيه قرر نقب صراع قدر إمكان تجنب غضب دولة عربيه منتج نفط زود بريطانيا جزء كبير احتياج نفط سياق حكومه بريطاني قياد زعيم حزب محافظ وقت إدوارد هيث قرر حظر تصدير اسلحه اطراف حرب احتلال إسرائيلي ودي ضرب كبير نسب اسرائيلي معنى حرمان قطع غيار دبابة سنتر بريطاني جيش إسرائيلي اعتمد كبير صد هجوم مصري سوري حكومه بريطاني رفض سمح امريكي ان استخدم قاعدة بريطاني امداد إسرائيلي عتاد سلاح موقف بريطاني براجماتي بحت حزب محافظ حاكم حط مصالح بريطانيا مصلحه اسرائيليه اثار غضب أنصار احتلال بريطانيا حال غضب سبب رئيسيه دفع يهودي مايكل فيدلر عضو برلمان بريطاني حزب محافظ ياسس لوبي جماع ضغط مناصر احتلال إسرائيلي داخل حزب محافظ كونسير فرينز أوف اسرائيل فيدلر أسس لوبي غرار لوبي تاني موجود داخل حزب عامل بريطاني اسم ليبور فرنز أوف اسرائيل أصدقاء اسرائيل حزب عامل اتاسس قبل كتير تحديد حرب أكتوبر حصل حزب عامل كانش حزب حاكم حكومه ساعة غريم حزب محافظ أنصار احتلال إسرائيلي شافي جماع ضغط داخل حزب رئيسي بريطانيا حزب محافظ مهم سن تأسس سي محافظ خسر حكومه صالح حزب عامل عضو برلمان بريطاني تابع حزب محافظ رأس مارجريت تاتشر انضم سي تأسيس إنجاز كبير أنصار احتلال إسرائيلي بدايه قويه سي ساهم دعم مالي قوي لوبي اثرياء يهودي بريطانيا ضمن مايكل ساشر نائب رئيس سلسل متجر تجزئه بريطاني شهيره ماركس أند سبنسر مهم أعضاء ح ...

# %%
from nltk.stem.isri import ISRIStemmer
st = ISRIStemmer()
def stem_text(text: str) -> str:
    return " ".join([st.stem(word) for word in text.split()])
text = df['cleaned_transcript'].iloc[0]
stem_text(text)
# Out:
# 'عمن قطر بحر سعد دول عرب ربع زار ملك برط امر يلز شارلز ثلث زوج امر يلز رحل امر ديا شارلز ودا لفا دول عرب ربع رحل مدت حقق رحل اعتياديه لىى كبر كنش شيء ميز ثيل همم حلي فجه رور رحل رجع بقت محط همم وسل علم بريطانيه صحف ديل ميل بريطانيه لقت رشف عام رسل ؤرخ ارخ شارلز بعت صدق كتب جنب فرق رنس ندر بوس رسل شارلز بيح رنس زير دول عرب لسه خلص شرح زير سعد فهم فضل وجه نظر عرب رائيل مهم مهم سيق شارلس صدق لنص رئس امر عند شجع يقف وش لوب يهد ولي تحد يوج بعد درك كتب عقد سذج فكر حصل رسل جرد خرج نور قلب دنا شارلز وقت ورث عرش برط قدم هجم كسح صار حلل اسرائيلي تحدث قصر بتع طلع جمع كتب رسل ارء امر شارلز شخص ارء شخص قبل زير دول عرب حقق نصل شارلز كتب رسل توقع كبر برط عرف صعب سمح ارء نوع جيه وطن برط عدي الش حيث بلك خرج شخص لكل عرف هيبقى ملك برط قبل وفه دته لكه زابيث شارلز رسل عمل شكل عير امر لوب ؤيد حلل اسرائيلي يزل ؤثر سيس شرق وسط تلف ايم برط بقى كان وجد اقى لوب جمع ضغط ؤيد حلل اسرائيلي ورب غرب كله لوب اسرائيلي لند ؤثر وجب عمر رغم حدش كلم قرب ركز كله لوب وجد شنط اكد قوه فعل نسب حلل اسرائيلي لنه يثر سيس اقى دول علم اثر عضء كونجرس فهم سيس ولي تحد حلل اسرائيلي قضه فلسطينيه عرب عرف نشط جمع ضغط ؤيد حلل ايب كنا حكي قصت حلق همه اسم حكم امر امر نسب برط قدر فهم سر ايد برط كسح حلل اسرائيلي عدو غزه فهم دور لعب اسرائيلي سيس بريطانيه ورا كواليس هندردش حلق شرف راهيم خبر قصد بلس حكم بريطانيه كمل قرب ومع ثلث عضء رلم برط عزم غدا ندق انتركونتيننتال وجد وسط عصم لند وخل احك فكر سرع غدى يوم كلم رئس زرء برط ريش سون ومع وزر حلي حكم راس وزر خرج ديفيد كامير حكم بريطانيه كله قرب غدى عرف عرف حكم بريطانيه كله بعض اصل وزر وزر حضرو غدا فخر عمل انتركونتيننتال غصب عنهم عند ربط قدروش لغو مهم غدا برد حضر عضو عضء رلم برط تبع حزب حفظ حكم ضفه ربع رؤساء زرء سبق برط برط رسم كله قرب غدى فيش حدث برط جمع سمء كله يخل تسل عزم عزم مهم مهم صحح صحب عزم مهم مهم رعي حفل عمل نسب ؤسس اسم كونسيف رينز اوف رائيل صدقاء رائيل حزب حفظ ؤسس عرف خصر سي ؤسس نار علم لند اقل نسب سيس افش سيس لند توج نمء حزب عرفش الس عند وطن عرب ؤسس عرف كبر رغم بذر اسس علق بشر بين قبل احك حكم بريطانيه عمل غدا ودا خلي شرح الس وله احدش حكم بريطانيه يفو غدا بتع خلو نبد حكي عنو كتب صحف سند يمز بريطانيه حدد عنو يقل بري اول سيف وي يهف اور سفز نفط برط امن حرم نفس صرف كوس عنو صحف بريطانيه كتب وقت دول غرب كله حله زعر دول عرب نجه نفط راس ملك عرب سعد قرر حظر صدر نفط دول سند حلل اسرائيلي حرب كتوبر خضه جيش صري سور حتل اسرائيلي عكس ولي تحد حاز وضح اسرائيلي برط فضل صلح لحت شخص قرر نقب صرع قدر امك جنب غضب دول عرب نجه نفط تزد برط جزء كبر احتياجات نفط سيق حكم بريطانيه قيد زعم حزب حفظ وقت درد هيث قرر حظر صدر سلح طرف حرب حلل اسرائيلي ودي ضرب كبر نسب اسرائيلي عنه حرم قطع غير دبب نتر بريطانيه جيش اسرائيلي عمد كبر صد هجم صري سور حكم بريطانيه رفض سمح امر نهم خدم قعد بريطانيه مدد اسرائيلي عتد سلح وقف برط براجماتي بحت حزب حفظ حكم حط صلح برط صلح اسرائيليه اثر غضب صار حلل برط حله غضب سبب رئس دفع يهد ايكل دلر عضو رلم برط حزب حفظ يسس لوب جمع ضغط نصر حلل اسرائيلي دخل حزب حفظ كونسير رينز اوف رائيل دلر اسس لوب غرر لوب تني وجد دخل حزب عمل برط اسم يبر رنز اوف رائيل صدقاء رائيل حزب عمل تسس قبل كتر حدد حرب كتوبر حصل حزب عمل كنش حزب حكم حكم سعت غرم حزب حفظ صار حلل اسرائيلي شاف جمع ضغط دخل حزب رئس برط حزب حفظ مهم سنه تسس الس حفظ خسر حكم صلح حزب عمل عضو رلم برط تبع حزب حفظ راس ارجر اشر نضم للس اسس جاز كبر صار حلل اسرائيلي بدي قوه للس سهم دعم الي قوي لوب ثرياء يهد برط ضمن ايكل سشر نئب رئس لسل تجر جزئ بريطانيه شهر اركس اند نسر مهم عضء حزب حفظ نضم وبي ؤيد حلل دخل حزب فضل يزد رور الس بقت كبر جمع ضغط سيس لند بقت كبر حت لوب ؤيد حلل دخل حزب عمل ضعف زمن تحل رئس زرء نقل نهي سبع حزب عمل حزب حفظ ارجر اشر زعم حزب حفظ كسب نخب وبق رئس زرء برط اشر عضو الس زيه زميل حزب حفظ سهم كبر شكل رسم سيس شرق وسط حرف دعم حلل اسرائيلي اوق عدو اسرائيلي لبن حكم اشر قرر فرض حظر صدر سلح اسرائيلي اشر وخذ لخط ؤيد اسرائيلي سيس سجم كون عضو الس اشر اصل بقى رئس زرء برط زرت اسرائيلي لسط حله رات ولم سكت حكم زرت لسط حله مره بقى رئس زرء برط يزر تله ابب وجد خدم مهم فضل اشر كسب نخب ورا حزب حفظ يطر قرر سيس لند لمد طول يطر مدت بعد لجن يجر حل محل اشر زعم حزب حفظ رئس حكم حفظ فضل حفظ سلط ورا خسر نخب قدم حزب عمل زعم تون بلر قوه لوب اسرائيلي دخل حزب حفظ الس زدت هئل درج ؤرخ عضو حزب حفظ روبر رودز جيمز وصف الس بان كبر ظمه ورب غر ...
